# %%
import requests
import os 
from bs4 import BeautifulSoup

# %%
url = 'http://api.citybik.es/v2/networks'

# %%
response = requests.get(url)

# %%
city = 'Moscow'

# %%
if response.status_code == 200:
    city_bikes = response.json()
    for network in city_bikes ['networks']:
        if network['location']['city'] == city:
            print(network)
else: print(f"Error: {responce.status_code}")
# Out:
# {'company': ['ЗАО «СитиБайк»'], 'href': '/v2/networks/velobike-moscow', 'id': 'velobike-moscow', 'location': {'city': 'Moscow', 'country': 'RU', 'latitude': 55.75, 'longitude': 37.616667}, 'name': 'Velobike'}

# %%
type(respoce_network)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 type(respoce_network)
#
# NameError: name 'respoce_network' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
import json

# %%
url_1 = 'http://api.citybik.es/v2/networks/velobike-moscow'

# %%
city_location = requests.get(url_1)

# %%
city = city_location.json()

# %%
print (city)
# Out:
# {'network': {'company': ['ЗАО «СитиБайк»'], 'href': '/v2/networks/velobike-moscow', 'id': 'velobike-moscow', 'location': {'city': 'Moscow', 'country': 'RU', 'latitude': 55.75, 'longitude': 37.616667}, 'name': 'Velobike', 'stations': [{'empty_slots': 1, 'extra': {'address': 'ст. м. Кропоткинская (выход к Гоголевскому бульвару)', 'ebikes': 1, 'electric_free': 0, 'electric_slots': 0, 'normal_bikes': 10, 'normal_free': 1, 'normal_slots': 12, 'slots': 12, 'uid': '0001'}, 'free_bikes': 11, 'id': 'c8a5761ea95e927808b2f37fd65a00f6', 'latitude': 55.7449006, 'longitude': 37.6020183, 'name': 'ст. м. Кропоткинская (выход к Гоголевскому бульвару)', 'timestamp': '2023-06-21T22:08:03.194000Z'}, {'empty_slots': 4, 'extra': {'address': 'ул. Профсоюзная, д.109, Вс.1 (ст. м. Коньково, выход №10)', 'ebikes': 0, 'electric_free': 0, 'electric_slots': 0, 'normal_bikes': 2, 'normal_free': 4, 'normal_slots': 6, 'slots': 6, 'uid': '0387'}, 'free_bikes': 2, 'id': 'ac022f0470de9722cc62e06ade73b0a6', 'latitude': 55.6337498, 'longitude': 37.5205529, 'name': 'ул. Профсоюзная, д.109, Вс.1 (ст. м. Коньково, выход №10)', 'timestamp': '2023-06-21T22:08:03.197000Z'}, {'empty_slots': 11, 'extra': {'address': 'ул. Новолесная, д.1/49', 'ebikes': 0, 'electric_free': 0, 'electric_slots': 0, 'normal_bikes': 1, 'normal_free': 11, 'normal_slots': 12, 'slots': 12, 'uid': '0405'}, 'free_bikes': 1, 'id': '17ffd07cf6b96ecd32b4980353290399', 'latitude': 55.7812396, 'longitude': 37.59239, 'name': 'ул. Новолесная, д.1/49', 'timestamp': '2023-06-21T22:08:03.198000Z'}, {'empty_slots': 13, 'extra': {'address': 'ул. Селезнёвская, д.29, стр.1 (ст. м. Достоевская)', 'ebikes': 1, 'electric_free': 0, 'electric_slots': 0, 'normal_bikes': 4, 'normal_free': 13, 'normal_slots': 18, 'slots': 18, 'uid': '0411'}, 'free_bikes': 5, 'id': '2a711f9eb3228be91abce39eca68e118', 'latitude': 55.7817849, 'longitude': 37.6144726, 'name': 'ул. Селезнёвская, д.29, стр.1 (ст. м. Достоевская)', 'timestamp': '2023-06-21T22:08:03.199000Z'}, {'empty_slots': 5, 'extra': {'address': 'ул. Новосущёвская, д.22, стр.8', 'ebikes': 2, 'electric_free': 0, 'electric_slots': 0, 'normal_bikes':
])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 for value in station :
# ----> 2     print (station['longitude'])
#
# TypeError: list indices must be integers or slices, not str

# %%
networkid_response = city_location.json()

# %%
networkid_response['network']['stations']
# Out:
# {'empty_slots': 4,
#  'extra': {'address': 'ул. Профсоюзная, д.109, Вс.1 (ст. м. Коньково, выход №10)',
#   'ebikes': 0,
#   'electric_free': 0,
#   'electric_slots': 0,
#   'normal_bikes': 2,
#   'normal_free': 4,
#   'normal_slots': 6,
#   'slots': 6,
#   'uid': '0387'},
#  'free_bikes': 2,
#  'id': 'ac022f0470de9722cc62e06ade73b0a6',
#  'latitude': 55.6337498,
#  'longitude': 37.5205529,
#  'name': 'ул. Профсоюзная, д.109, Вс.1 (ст. м. Коньково, выход №10)',
#  'timestamp': '2023-06-21T22:08:03.197000Z'}

# %%
city_df = pd.DataFrame(city_location.json())

# %%
city_df.head(10)
# Out:
#                                                     network
# company                                    [ЗАО «СитиБайк»]
# href                           /v2/networks/velobike-moscow
# id                                          velobike-moscow
# location  {'city': 'Moscow', 'country': 'RU', 'latitude'...
# name                                               Velobike
# stations  [{'empty_slots': 1, 'extra': {'address': 'ст. ...

# %%
import pybike
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[228], line 1
# ----> 1 import pybike
#
# ModuleNotFoundError: No module named 'pybike'

# %%
df = pd.DataFrame(response.json())

# %%
df.head
# Out:
# <bound method NDFrame.head of                                               networks
# 0    {'company': ['ЗАО «СитиБайк»'], 'href': '/v2/n...
# 1    {'company': ['Urban Infrastructure Partner'], ...
# 2    {'company': ['Comunicare S.r.l.'], 'href': '/v...
# 3    {'company': ['Cyclopolis Systems'], 'href': '/...
# 4    {'company': ['Groundwork', 'Slough Borough Cou...
# ..                                                 ...
# 607  {'company': ['PubliBike AG'], 'href': '/v2/net...
# 608  {'company': ['PubliBike AG'], 'href': '/v2/net...
# 609  {'company': ['PubliBike AG'], 'href': '/v2/net...
# 610  {'company': ['PubliBike AG'], 'href': '/v2/net...
# 611  {'company': ['Citybike Normandie', 'INURBA Mob...
#
# [612 rows x 1 columns]>

# %%
url_2 = 'http://api.citybik.es/v2/networks/network_id'

# %%
network_detiles = requests.get(url_2)

# %%
df_networkid
# Out:
#                                                     network
# company                                    [ЗАО «СитиБайк»]
# href                           /v2/networks/velobike-moscow
# id                                          velobike-moscow
# location  {'city': 'Moscow', 'country': 'RU', 'latitude'...
# name                                               Velobike
# stations  [{'empty_slots': 1, 'extra': {'address': 'ст. ...

# %%
url_1 = 'http://api.citybik.es/v2/networks/'
params_dict = { 
             'location' : {'city': 'Moscow',
    'country': 'RU',
    'latitude': 55.75,
    'longitude': 37.616667}
              }
headers_dict = {'accept': 'application/JSON'}
response = requests.get(url_1, params=params_dict, headers=headers_dict)
res_json = response.json()
res_json ['networks'][600]['location']['city']
# Out:
# 'Saint-Brieuc'

# %%
res_json ['networks'][600]['location']['city']
# Out:
# 'Saint-Brieuc'

# %%
url = 'https://api.citybik.es/v2/networks'

# %%
city = 'Bærum'

# %%
response = requests.get(url)

# %%
if response.status_code == 200:
    data = response.json()
    for network in data['networks']:
        if network['location']['city'] == city:
            company_name  = network['company']
            latitude = network['location']['latitude']
            longitude = network['location']['longitude']
                
            print(f"Station: {company_name}")
            print(f"Latitude: {latitude}")
            print(f"Longitude: {longitude}")
# Out:
# Station: ['Urban Infrastructure Partner']
# Latitude: 59.89455
# Longitude: 10.546343
# -----------------------------
# Error: 200 - OK
